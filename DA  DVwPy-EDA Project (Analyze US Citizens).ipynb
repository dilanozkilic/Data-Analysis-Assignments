# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis & Visualization with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Project Solution</p>
#
# ![image.png](https://i.ibb.co/mT1GG7j/US-citizen.jpg)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Analysis of US Citizens by Income Levels</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [Introduction](#0)
# * [Dataset Info](#1)
# * [Importing Related Libraries](#2)
# * [Recognizing & Understanding Data](#3)
# * [Univariate & Multivariate Analysis](#4)
# * [Other Specific Analysis Questions](#5)
# * [Dropping Similar & Unneccessary Features](#6)
# * [Handling with Missing Values](#7)
# * [Handling with Outliers](#8)
# * [Final Step to make ready dataset for ML Models](#9)
# * [The End of the Project](#10)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Introduction</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# One of the most important components to any data science experiment that doesn’t get as much importance as it should is **``Exploratory Data Analysis (EDA)``**. In short, EDA is **``"A first look at the data"``**. It is a critical step in analyzing the data from an experiment. It is used to understand and summarize the content of the dataset to ensure that the features which we feed to our machine learning algorithms are refined and we get valid, correctly interpreted results.
# In general, looking at a column of numbers or a whole spreadsheet and determining the important characteristics of the data can be very tedious and boring. Moreover, it is good practice to understand the problem statement and the data before you get your hands dirty, which in view, helps to gain a lot of insights. I will try to explain the concept using the Adult dataset/Census Income dataset available on the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Adult). The problem statement here is to predict whether the income exceeds 50k a year or not based on the census data.
#
# # Aim of the Project
#
# Applying Exploratory Data Analysis (EDA) and preparing the data to implement the Machine Learning Algorithms;
# 1. Analyzing the characteristics of individuals according to income groups
# 2. Preparing data to create a model that will predict the income levels of people according to their characteristics (So the "salary" feature is the target feature)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 48,842 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Installing/Enabling Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Related Libraries</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:left; border-radius:10px 10px;">Reading the data from file</p>

# %%
citizen = pd.read_csv("/Users/dilanozkilic/Desktop/EDA/adult_eda.csv")

# %%
citizen.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Recognizing and Understanding Data</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ### 1.Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - If needed, rename the columns' names for easy use.
# - Basically check the missing values.

# %%
citizen.shape
# Out:
# (32561, 15)

# %%
citizen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
citizen.describe()
# Out:
#             age      fnlwgt  education-num  capital-gain  capital-loss  \
# count 32561.000   32561.000      31759.000     32561.000     32561.000
# mean     38.582  189778.367         10.083      1077.649        87.304
# std      13.640  105549.978          2.576      7385.292       402.960
# min      17.000   12285.000          1.000         0.000         0.000
# 25%      28.000  117827.000          9.000         0.000         0.000
# 50%      37.000  178356.000         10.000         0.000         0.000
# 75%      48.000  237051.000         12.000         0.000         0.000
# max      90.000 1484705.000         16.000     99999.000      4356.000
#
#        hours-per-week
# count       32561.000
# mean           40.437
# std            12.347
# min             1.000
# 25%            40.000
# 50%            40.000
# 75%            45.000
# max            99.000

# %% [markdown]
# #### Let's see if there are any duplicated rows, if drop them;

# %%
citizen.duplicated().sum()
# Out:
# 24

# %%
citizen.drop_duplicates()
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors         13.000
# 1       50  Self-emp-not-inc   83311   Bachelors         13.000
# 2       38           Private  215646     HS-grad          9.000
# 3       53           Private  234721        11th          7.000
# 4       28           Private  338409   Bachelors         13.000
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm         12.000
# 32557   40           Private  154374     HS-grad          9.000
# 32558   58           Private  151910     HS-grad          9.000
# 32559   22           Private  201490     HS-grad          9.000
# 32560   52      Self-emp-inc  287927     HS-grad          9.000
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# #### Rename the features of;
# #### "education-num", "marital-status", "capital-gain", "capital-loss", "hours-per-week", "native-country" as
# #### "education_num", "marital_status", "capital_gain", "capital_loss", "hours_per_week", "native_country", respectively and permanently.

# %%
citizen.rename(columns=({"education-num":"education_num", "marital-status": "marital_status", "capital-gain": "capital_gain", "capital-loss": "capital_loss", "hours-per-week": "hours_per_week", "native-country": "native_country"}), inplace=True)

# %%
citizen.head(1)
# Out:
#    age  workclass  fnlwgt  education  education_num marital_status  \
# 0   39  State-gov   77516  Bachelors         13.000  Never-married
#
#      occupation   relationship   race   sex  capital_gain  capital_loss  \
# 0  Adm-clerical  Not-in-family  White  Male          2174             0
#
#    hours_per_week native_country salary
# 0              40  United-States  <=50K

# %% [markdown]
# #### Let's check the Percentage of Missing Values

# %%
citizen.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
(citizen.isnull().sum()/citizen.count())*100
# Out:
# age               0.000
# workclass         0.000
# fnlwgt            0.000
# education         0.000
# education_num     2.525
# marital_status    0.000
# occupation        0.000
# relationship     18.434
# race              0.000
# sex               0.000
# capital_gain      0.000
# capital_loss      0.000
# hours_per_week    0.000
# native_country    0.000
# salary            0.000
# dtype: float64

# %% [markdown]
# ### 2.Look at the value counts of columns that have object datatype and detect strange values apart from the NaN Values

# %%
columns = citizen.columns
columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
column_objects = []

for i in columns:
    if citizen[i].dtype == "object" :
        column_objects.append(i)

# %%
column_objects
# Out:
# ['workclass',
#  'education',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country',
#  'salary']

# %%
citizen.select_dtypes(include=[object]).describe().T
# Out:
#                 count unique                 top   freq
# workclass       32561      9             Private  22696
# education       32561     16             HS-grad  10501
# marital_status  32561      7  Married-civ-spouse  14976
# occupation      32561     15      Prof-specialty   4140
# relationship    27493      5             Husband  13193
# race            32561      5               White  27816
# sex             32561      2                Male  21790
# native_country  32561     42       United-States  29170
# salary          32561      2               <=50K  24720

# %%
for col in column_objects:
    print(col)
    print("--"*8)
    print(citizen[col].value_counts(dropna=False))
    print("\n"*2)
# Out:
# workclass
# ----------------
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
#
#
#
# education
# ----------------
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64
#
#
#
# marital_status
# ----------------
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# ...

# %% [markdown]
# #### We see that sum columns have ? value, let's look which columns have it;

# %%
for x in columns:
    if citizen[x].isin(["?"]).sum() >= 1:
        print(x, True)
# Out:
# workclass True
# occupation True
# native_country True

# %%
print((citizen.astype(str) == '?').any())
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %%
for x in column_objects:
    print(x, citizen[x].isin(["?"]).sum())
# Out:
# workclass 1836
# education 0
# marital_status 0
# occupation 1843
# relationship 0
# race 0
# sex 0
# native_country 583
# salary 0

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Univariate & Multivariate Analysis</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Examine all features (first target feature("salary"), then numeric ones, lastly categoric ones) separetly from different aspects according to target feature.
#
# **to do list for numeric features:**
# 1. Check the boxplot to see extreme values
# 2. Check the histplot/kdeplot to see distribution of feature
# 3. Check the statistical values
# 4. Check the boxplot and histplot/kdeplot by "salary" levels
# 5. Check the statistical values by "salary" levels
# 6. Write down the conclusions you draw from your analysis
#
# **to do list for categoric features:**
# 1. Find the features which contains similar values, examine the similarities and analyze them together
# 2. Check the count/percentage of person in each categories and visualize it with a suitable plot
# 3. If need, decrease the number of categories by combining similar categories
# 4. Check the count of person in each "salary" levels by categories and visualize it with a suitable plot
# 5. Check the percentage distribution of person in each "salary" levels by categories and visualize it with suitable plot
# 6. Check the count of person in each categories by "salary" levels and visualize it with a suitable plot
# 7. Check the percentage distribution of person in each categories by "salary" levels and visualize it with suitable plot
# 8. Write down the conclusions you draw from your analysis
#
# **Note :** Instruction/direction for each feature is available under the corresponding feature in detail, as well.

# %% [markdown]
# ## 1-) Salary (Target Feature)

# %%
citizen.salary.value_counts()
# Out:
# <=50K    24720
# >50K      7841
# Name: salary, dtype: int64

# %%
ax = sns.countplot(x="salary", data=citizen)
ax.bar_label(ax.containers[0]);

# %% [markdown]
# #### Check the percentage of person in each "salary" levels and visualize it with a pieplot

# %%
salary_pie = citizen.salary.value_counts()/citizen.salary.count().sum()

# %%
label = ["<=50K ", ">=50K "]
explode=(0 , 0.1)
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
plt.pie(salary_pie, explode=explode, labels = label, colors=colors, autopct='%.2f%%', shadow=True)
plt.title("Percentage of Income Levels");

# %% [markdown]
# #### Result

# %% [markdown]
# More than half of people work for less than 50K annually.

# %% [markdown]
# ## 2-) Age

# %%
ax = sns.boxplot(x=citizen["age"]);

# %%
ax = sns.histplot(x=citizen["age"],bins=20,kde=True);

# %%
citizen.age.describe()
# Out:
# count   32561.000
# mean       38.582
# std        13.640
# min        17.000
# 25%        28.000
# 50%        37.000
# 75%        48.000
# max        90.000
# Name: age, dtype: float64

# %% [markdown]
# #### Age Feature by Salary

# %%
ax = sns.boxplot(x="salary",y="age", data=citizen);

# %%
ax = sns.histplot(x="age",bins=20,kde=True, hue="salary", data=citizen);

# %%
ax = sns.kdeplot(x="age", hue="salary", data=citizen, shade=True);

# %%
citizen.groupby("salary").age.describe()
# Out:
#            count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  24720.000 36.784 14.020 17.000 25.000 34.000 46.000 90.000
# >50K    7841.000 44.250 10.519 19.000 36.000 44.000 51.000 90.000

# %% [markdown]
# #### Result

# %% [markdown]
# The mean and median age of the high-income group is higher than the low-income group and the majority of the dataset makes less than 50k annually. People who make more than 50k have a mean age of 44 which is older than the mean of people who make more than 50k annualy with the value 36 years.

# %% [markdown]
# # 3-) fnlwgt

# %%
ax = sns.boxplot(x="fnlwgt", data=citizen);

# %%
ax = sns.kdeplot(x="fnlwgt",shade=True, data=citizen);

# %%
citizen["fnlwgt"].describe()
# Out:
# count     32561.000
# mean     189778.367
# std      105549.978
# min       12285.000
# 25%      117827.000
# 50%      178356.000
# 75%      237051.000
# max     1484705.000
# Name: fnlwgt, dtype: float64

# %% [markdown]
# #### fnlwgt Feature by Salary

# %%
ax = sns.boxplot(x="salary",y="fnlwgt", data=citizen);

# %%
ax = sns.kdeplot(x="fnlwgt",hue="salary", data=citizen, shade=True);

# %%
citizen.groupby("salary").fnlwgt.describe()
# Out:
#            count       mean        std       min        25%        50%  \
# salary
# <=50K  24720.000 190340.865 106482.271 12285.000 117606.000 179465.000
# >50K    7841.000 188005.000 102541.775 14878.000 119101.000 176101.000
#
#               75%         max
# salary
# <=50K  239023.000 1484705.000
# >50K   230959.000 1226583.000

# %% [markdown]
# #### Conclusions

# %% [markdown]
# There is no significant difference between high and low-income groups according to the "fnlwgt" feature.

# %% [markdown]
# # 4-) Capital Gain

# %%
ax = sns.boxplot(x="capital_gain", data=citizen);

# %%
ax = sns.kdeplot(x="capital_gain",shade=True, data=citizen);

# %%
citizen.capital_gain.describe()
# Out:
# count   32561.000
# mean     1077.649
# std      7385.292
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max     99999.000
# Name: capital_gain, dtype: float64

# %% [markdown]
# #### Capital Gain Feature by Salary

# %%
ax = sns.boxplot(x="salary",y="capital_gain", data=citizen);

# %%
ax = sns.kdeplot(x="capital_gain",hue="salary", data=citizen, shade=True);

# %%
citizen.groupby("salary").capital_gain.describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24720.000  148.752   963.139 0.000 0.000 0.000 0.000 41310.000
# >50K    7841.000 4006.142 14570.379 0.000 0.000 0.000 0.000 99999.000

# %%
citizen[citizen["capital_gain"] != 0].groupby("salary").capital_gain.describe()
# Out:
#           count      mean       std      min      25%      50%       75%  \
# salary
# <=50K  1035.000  3552.813  3173.419  114.000 2202.000 3273.000  4101.000
# >50K   1677.000 18731.165 26778.676 3103.000 7298.000 7896.000 15024.000
#
#              max
# salary
# <=50K  41310.000
# >50K   99999.000

# %% [markdown]
# #### Conclusions

# %% [markdown]
# The "capital-gain" feature has not provided very meaningful insights. Nevertheless, we can say that the more "capital-gain", the more "high-income".

# %% [markdown]
# # 5-) Capital Loss

# %%
ax = sns.boxplot(x="capital_loss", data=citizen);

# %%
ax = sns.kdeplot(x="capital_loss",shade=True, data=citizen);

# %%
citizen.capital_loss.describe()
# Out:
# count   32561.000
# mean       87.304
# std       402.960
# min         0.000
# 25%         0.000
# 50%         0.000
# 75%         0.000
# max      4356.000
# Name: capital_loss, dtype: float64

# %% [markdown]
# #### Capital Loss Feature by Salary

# %%
ax = sns.boxplot(x="salary",y="capital_loss", data=citizen);

# %%
ax = sns.kdeplot(x="capital_loss",hue="salary", data=citizen, shade=True);

# %%
citizen.groupby("salary").capital_gain.describe()
# Out:
#            count     mean       std   min   25%   50%   75%       max
# salary
# <=50K  24720.000  148.752   963.139 0.000 0.000 0.000 0.000 41310.000
# >50K    7841.000 4006.142 14570.379 0.000 0.000 0.000 0.000 99999.000

# %%
citizen[citizen["capital_loss"] != 0].groupby("salary").capital_loss.describe()
# Out:
#          count     mean     std     min      25%      50%      75%      max
# salary
# <=50K  746.000 1760.983 438.906 155.000 1590.000 1721.000 1980.000 4356.000
# >50K   773.000 1978.017 264.144 653.000 1887.000 1902.000 1977.000 3683.000

# %% [markdown]
# #### Conclusions

# %% [markdown]
# There is no significant difference between high and low-income groups according to the "capital_loss" feature.

# %% [markdown]
# # 6-) Hours per Week

# %%
ax = sns.boxplot(x="hours_per_week", data=citizen);

# %%
ax = sns.kdeplot(x="hours_per_week",shade=True, data=citizen);

# %%
citizen.hours_per_week.describe()
# Out:
# count   32561.000
# mean       40.437
# std        12.347
# min         1.000
# 25%        40.000
# 50%        40.000
# 75%        45.000
# max        99.000
# Name: hours_per_week, dtype: float64

# %% [markdown]
# #### Hours by Salary Levels

# %%
ax = sns.boxplot(x="salary",y="hours_per_week", data=citizen);

# %%
ax = sns.kdeplot(x="hours_per_week",hue="salary", data=citizen, shade=True);

# %%
citizen.groupby("salary").hours_per_week.describe()
# Out:
#            count   mean    std   min    25%    50%    75%    max
# salary
# <=50K  24720.000 38.840 12.319 1.000 35.000 40.000 40.000 99.000
# >50K    7841.000 45.473 11.013 1.000 40.000 40.000 50.000 99.000

# %% [markdown]
# #### Result:

# %% [markdown]
# To be in a high-income group, almost at least 40 hours working per week is required. Most of those who work less than 40 hours per week are in the low-income group.

# %% [markdown]
# ### Let's see the relationship between each numeric features by target feature (salary) in one plot basically

# %%
sns.pairplot(data=citizen, hue="salary", corner=True, palette="husl");

# %% [markdown]
# # Categorical Features

# %% [markdown]
# # 7-) Education and Education_num

# %% [markdown]
# Let's look at the similarities between these features by comparing unique values

# %%
citizen.education.unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
citizen.education_num.unique()
# Out:
# array([13.,  9.,  7., 14.,  5., 10., 12., nan,  4., 16., 11., 15.,  3.,
#         6.,  2.,  1.,  8.])

# %%
citizen.education.value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
citizen.education_num.value_counts(dropna=False)
# Out:
# 9.000     10215
# 10.000     7098
# 13.000     5247
# 14.000     1687
# 11.000     1343
# 7.000      1146
# 12.000     1044
# 6.000       916
# NaN         802
# 4.000       631
# 15.000      559
# 5.000       503
# 8.000       424
# 16.000      405
# 3.000       330
# 2.000       161
# 1.000        50
# Name: education_num, dtype: int64

# %%
citizen.groupby("education").education_num.value_counts(dropna=False)
# Out:
# education     education_num
# 10th          6.000              916
#               NaN                 17
# 11th          7.000             1146
#               NaN                 29
# 12th          8.000              424
#               NaN                  9
# 1st-4th       2.000              161
#               NaN                  7
# 5th-6th       3.000              330
#               NaN                  3
# 7th-8th       4.000              631
#               NaN                 15
# 9th           5.000              503
#               NaN                 11
# Assoc-acdm    12.000            1044
#               NaN                 23
# Assoc-voc     11.000            1343
#               NaN                 39
# Bachelors     13.000            5247
#               NaN                108
# Doctorate     16.000             405
#               NaN                  8
# HS-grad       9.000            10215
#               NaN                286
# ...

# %% [markdown]
# #### Count Plot

# %%
sns.countplot(x="education", data=citizen)
plt.xticks(rotation=45);

# %%
sns.countplot(x="education_num", data=citizen)
plt.xticks(rotation=45);

# %% [markdown]
# #### Feature by Salary Level

# %%
citizen.groupby("education").salary.value_counts()
# Out:
# education     salary
# 10th          <=50K      871
#               >50K        62
# 11th          <=50K     1115
#               >50K        60
# 12th          <=50K      400
#               >50K        33
# 1st-4th       <=50K      162
#               >50K         6
# 5th-6th       <=50K      317
#               >50K        16
# 7th-8th       <=50K      606
#               >50K        40
# 9th           <=50K      487
#               >50K        27
# Assoc-acdm    <=50K      802
#               >50K       265
# Assoc-voc     <=50K     1021
#               >50K       361
# Bachelors     <=50K     3134
#               >50K      2221
# Doctorate     >50K       306
#               <=50K      107
# HS-grad       <=50K     8826
#               >50K      1675
# Masters       >50K       959
#               <=50K      764
# Preschool     <=50K       51
# Prof-school   >50K       423
#               <=50K      153
# Some-college  <=50K     5904
#               >50K      1387
# ...

# %%
sns.countplot(x="education", hue="salary", data=citizen)
plt.xticks(rotation=45);

# %%
citizen.groupby("education_num").salary.value_counts()
# Out:
# education_num  salary
# 1.000          <=50K       50
# 2.000          <=50K      155
#                >50K         6
# 3.000          <=50K      314
#                >50K        16
# 4.000          <=50K      593
#                >50K        38
# 5.000          <=50K      477
#                >50K        26
# 6.000          <=50K      854
#                >50K        62
# 7.000          <=50K     1088
#                >50K        58
# 8.000          <=50K      391
#                >50K        33
# 9.000          <=50K     8585
#                >50K      1630
# 10.000         <=50K     5754
#                >50K      1344
# 11.000         <=50K      994
#                >50K       349
# 12.000         <=50K      787
#                >50K       257
# 13.000         <=50K     3080
#                >50K      2167
# 14.000         >50K       935
#                <=50K      752
# 15.000         >50K       410
#                <=50K      149
# 16.000         >50K       302
# ...

# %%
sns.countplot(x="education_num", hue="salary", data=citizen)
plt.xticks(rotation=45);

# %%
sns.boxplot(y="education_num", x="salary", data=citizen);

# %% [markdown]
# #### Filling Missing Values of Education Num by Usinf Education Feature

# %%
citizen_coppy = citizen.copy()

# %%
citizen_coppy['education_num'] = citizen_coppy['education_num'].fillna(citizen_coppy.groupby('education')['education_num'].transform(lambda x: x.value_counts().idxmax()))

# %%
citizen['education_num'] = citizen['education_num'].fillna(citizen.groupby('education')['education_num'].transform(lambda x: x.value_counts().idxmax()))

# %%
citizen_coppy.groupby("education").education_num.value_counts(dropna=False)
# Out:
# education     education_num
# 10th          6.000              933
# 11th          7.000             1175
# 12th          8.000              433
# 1st-4th       2.000              168
# 5th-6th       3.000              333
# 7th-8th       4.000              646
# 9th           5.000              514
# Assoc-acdm    12.000            1067
# Assoc-voc     11.000            1382
# Bachelors     13.000            5355
# Doctorate     16.000             413
# HS-grad       9.000            10501
# Masters       14.000            1723
# Preschool     1.000               51
# Prof-school   15.000             576
# Some-college  10.000            7291
# Name: education_num, dtype: int64

# %% [markdown]
# ### Let's decrease the number of categories in "education" feature as low, medium, and high level and create a new feature with this new categorical data.

# %%
def mapping_ed(status):
    if status in ["Preschool","1st-4th", "5th-6th", "7th-8th" ,"9th", "10th", "11th", "12th"]:
        return "low_level_ed"
    elif status in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "medium_level_ed"
    else:
        return "high_level_ed"

# %%
citizen["education_summary"]=citizen["education"].transform(mapping_ed)

# %%
citizen.sample(3)
# Out:
#        age     workclass  fnlwgt  education  education_num  \
# 29636   30  Self-emp-inc   77689  Bachelors         13.000
# 11394   45       Private  186272    HS-grad          9.000
# 18040   53     Local-gov  293941  Bachelors         13.000
#
#            marital_status         occupation relationship   race   sex  \
# 29636  Married-civ-spouse              Sales      Husband  White  Male
# 11394  Married-civ-spouse  Handlers-cleaners      Husband  Black  Male
# 18040  Married-civ-spouse     Prof-specialty      Husband  White  Male
#
#        capital_gain  capital_loss  hours_per_week native_country salary  \
# 29636          7688             0              50  United-States   >50K
# 11394          7298             0              40  United-States   >50K
# 18040             0             0              40  United-States  <=50K
#
#       education_summary
# 29636     high_level_ed
# 11394   medium_level_ed
# 18040     high_level_ed

# %% [markdown]
# #### Visualize the count of person in each categories for these new education levels (high, medium, low)

# %%
citizen.education_summary.value_counts()
# Out:
# medium_level_ed    20241
# high_level_ed       8067
# low_level_ed        4253
# Name: education_summary, dtype: int64

# %%
ax = sns.countplot(data=citizen, x="education_summary");

# %%
citizen.groupby("education_summary")["salary"].value_counts()
# Out:
# education_summary  salary
# high_level_ed      <=50K      4158
#                    >50K       3909
# low_level_ed       <=50K      4009
#                    >50K        244
# medium_level_ed    <=50K     16553
#                    >50K       3688
# Name: salary, dtype: int64

# %%
ax = sns.countplot(data=citizen, x="education_summary", hue="salary");

# %%
citizen.groupby("education_summary")["salary"].value_counts(normalize=True)
# Out:
# education_summary  salary
# high_level_ed      <=50K    0.515
#                    >50K     0.485
# low_level_ed       <=50K    0.943
#                    >50K     0.057
# medium_level_ed    <=50K    0.818
#                    >50K     0.182
# Name: salary, dtype: float64

# %%
a = citizen.groupby("education_summary")["salary"].value_counts(normalize=True).unstack(level=0)
a
# Out:
# education_summary  high_level_ed  low_level_ed  medium_level_ed
# salary
# <=50K                      0.515         0.943            0.818
# >50K                       0.485         0.057            0.182

# %%
colors = ['pink', 'steelblue']

ax = a.plot(kind="pie", subplots=True,figsize=(14, 8), layout=(1,3), autopct='%1.1f%%', 
            title=["high_level_ed", "low_level_ed", "medium_level_ed"],
            legend=False, colors=colors,
            ylabel="Salary");

# %% [markdown]
# #### Let's check the count of person in each these new education levels(high, medium, low) by "salary" levels and visualize it

# %%
citizen.groupby("salary")["education_summary"].value_counts()
# Out:
# salary  education_summary
# <=50K   medium_level_ed      16553
#         high_level_ed         4158
#         low_level_ed          4009
# >50K    high_level_ed         3909
#         medium_level_ed       3688
#         low_level_ed           244
# Name: education_summary, dtype: int64

# %%
ax = sns.countplot(data=citizen, x="salary", hue="education_summary");

# %%
citizen.groupby("salary")["education_summary"].value_counts(normalize=True)
# Out:
# salary  education_summary
# <=50K   medium_level_ed     0.670
#         high_level_ed       0.168
#         low_level_ed        0.162
# >50K    high_level_ed       0.499
#         medium_level_ed     0.470
#         low_level_ed        0.031
# Name: education_summary, dtype: float64

# %%
c = citizen.groupby("salary")["education_summary"].value_counts().unstack(level=0)
c
# Out:
# salary             <=50K  >50K
# education_summary
# high_level_ed       4158  3909
# low_level_ed        4009   244
# medium_level_ed    16553  3688

# %%
colors=['pink','silver', 'steelblue']

ax = c.plot(kind="pie", subplots=True,figsize=(14, 8),
            title=["<=50K", ">50K"], ylabel="Education Summary",
            autopct='%1.1f%%', legend=False, startangle=45, colors=colors);

# %%
df = citizen.groupby("salary")["education_summary"].value_counts(normalize=True).unstack(level=0)
df
# Out:
# salary             <=50K  >50K
# education_summary
# high_level_ed      0.168 0.499
# low_level_ed       0.162 0.031
# medium_level_ed    0.670 0.470

# %%
dff = citizen.groupby("salary")["education_summary"].value_counts(normalize=True).to_frame()
dff.columns = ["percentages"]
dff.reset_index(inplace=True)
dff
# Out:
#   salary education_summary  percentages
# 0  <=50K   medium_level_ed        0.670
# 1  <=50K     high_level_ed        0.168
# 2  <=50K      low_level_ed        0.162
# 3   >50K     high_level_ed        0.499
# 4   >50K   medium_level_ed        0.470
# 5   >50K      low_level_ed        0.031

# %%
colors=['pink','silver', 'steelblue']

ax = df.plot(kind="pie", subplots=True,figsize=(14, 8),
            title=["<=50K", ">50K"], ylabel="Education Summary",
            autopct='%1.1f%%', legend=False, startangle=45, colors=colors);

# %% [markdown]
# #### Conclusions

# %% [markdown]
# People with higher educational status tend to earn more. Almost none of people with low level of education makes more than 50k annually.

# %% [markdown]
# # Marital Status & Relationship

# %% [markdown]
# Let's detect the similarities between these features by comparing unique values

# %%
citizen.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
citizen.marital_status.value_counts(dropna=False)
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64

# %%
citizen.relationship.value_counts(dropna=False)
# Out:
# Husband           13193
# Not-in-family      8305
# NaN                5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %% [markdown]
# #### We fill missing values with "Unknown" in the column of "relationship"

# %%
citizen.relationship.fillna("Unknown", inplace=True)

# %%
citizen.groupby("relationship").marital_status.value_counts(dropna=False)
# Out:
# relationship    marital_status
# Husband         Married-civ-spouse       13184
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4706
#                 Divorced                  2404
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unknown         Never-married             4485
#                 Divorced                   328
#                 Separated                   99
#                 Married-civ-spouse          95
# ...

# %%
sns.countplot(data=citizen, x="marital_status");

# %%
citizen.groupby("marital_status")["salary"].value_counts()
# Out:
# marital_status         salary
# Divorced               <=50K      3980
#                        >50K        463
# Married-AF-spouse      <=50K        13
#                        >50K         10
# Married-civ-spouse     <=50K      8284
#                        >50K       6692
# Married-spouse-absent  <=50K       384
#                        >50K         34
# Never-married          <=50K     10192
#                        >50K        491
# Separated              <=50K       959
#                        >50K         66
# Widowed                <=50K       908
#                        >50K         85
# Name: salary, dtype: int64

# %%
sns.countplot(data=citizen, x="marital_status", hue="salary");

# %% [markdown]
# #### **Let's decrease the number of categories in "marital_status" feature as married, and unmarried and create a new feature with this new categorical data**

# %%
def mapping_marriage(status):
    if status in ["Divorced","Never-married", "Separated", "Widowed"]:
        return "unmarried"
    else:
        return "married"

# %%
citizen["marital_status_summary"] = citizen["marital_status"].transform(mapping_marriage)

# %%
citizen["marital_status_summary"].value_counts()
# Out:
# unmarried    17144
# married      15417
# Name: marital_status_summary, dtype: int64

# %%
sns.countplot(data=citizen, x="marital_status_summary");

# %%
citizen.groupby("marital_status_summary")["salary"].value_counts()
# Out:
# marital_status_summary  salary
# married                 <=50K      8681
#                         >50K       6736
# unmarried               <=50K     16039
#                         >50K       1105
# Name: salary, dtype: int64

# %%
sns.countplot(data=citizen, x="marital_status_summary", hue="salary");

# %%
citizen.groupby("marital_status_summary")["salary"].value_counts(normalize=True)
# Out:
# marital_status_summary  salary
# married                 <=50K    0.563
#                         >50K     0.437
# unmarried               <=50K    0.936
#                         >50K     0.064
# Name: salary, dtype: float64

# %%
colors = ["pink", "steelblue"]

f = citizen.groupby("marital_status_summary")["salary"].value_counts().unstack(level=0)

f.plot(kind="pie", subplots=True, autopct='%1.2f%%',
       title=["Married", "Unmarried"], ylabel="Salary",
       legend=False, colors=colors);

# %% [markdown]
# #### Let's check the count of person in each these new marital status (married, unmarried) by "salary" levels and visualize it

# %%
sns.countplot(data=citizen, x="salary", hue="marital_status_summary");

# %%
citizen.groupby("salary")["marital_status_summary"].value_counts(normalize=True)
# Out:
# salary  marital_status_summary
# <=50K   unmarried                0.649
#         married                  0.351
# >50K    married                  0.859
#         unmarried                0.141
# Name: marital_status_summary, dtype: float64

# %%
df2 = citizen.groupby("salary")["marital_status_summary"].value_counts(normalize=True).to_frame()
df2.columns = ["percentages"]
df2.reset_index(inplace=True)
df2
# Out:
#   salary marital_status_summary  percentages
# 0  <=50K              unmarried        0.649
# 1  <=50K                married        0.351
# 2   >50K                married        0.859
# 3   >50K              unmarried        0.141

# %%
colors = ["pink", "steelblue"]

f = citizen.groupby("salary")["marital_status_summary"].value_counts().unstack(level=0)

f.plot(kind="pie", subplots=True, autopct='%1.2f%%',
       title=["<=50K", ">50K"], ylabel="Percentage",
       legend=False, colors=colors);

# %% [markdown]
# #### Conclusions

# %% [markdown]
# 85% of people who make more than 50K annually are married. Among married people 56% make more than 50K annually.

# %% [markdown]
# # Workclass

# %%
citizen.workclass.value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
sns.countplot(data=citizen, x="workclass");

# %% [markdown]
# #### Replace the value "?" to the value "Unknown"

# %%
citizen.workclass.replace("?", "Unknown", inplace=True)

# %%
citizen.groupby("workclass")["salary"].value_counts()
# Out:
# workclass         salary
# Federal-gov       <=50K       589
#                   >50K        371
# Local-gov         <=50K      1476
#                   >50K        617
# Never-worked      <=50K         7
# Private           <=50K     17733
#                   >50K       4963
# Self-emp-inc      >50K        622
#                   <=50K       494
# Self-emp-not-inc  <=50K      1817
#                   >50K        724
# State-gov         <=50K       945
#                   >50K        353
# Unknown           <=50K      1645
#                   >50K        191
# Without-pay       <=50K        14
# Name: salary, dtype: int64

# %% [markdown]
# #### Examining the Feature by Salary Level

# %%
sns.countplot(data=citizen, x="workclass", hue="salary");

# %%
citizen.groupby("workclass")["salary"].value_counts(normalize=True)
# Out:
# workclass         salary
# Federal-gov       <=50K    0.614
#                   >50K     0.386
# Local-gov         <=50K    0.705
#                   >50K     0.295
# Never-worked      <=50K    1.000
# Private           <=50K    0.781
#                   >50K     0.219
# Self-emp-inc      >50K     0.557
#                   <=50K    0.443
# Self-emp-not-inc  <=50K    0.715
#                   >50K     0.285
# State-gov         <=50K    0.728
#                   >50K     0.272
# Unknown           <=50K    0.896
#                   >50K     0.104
# Without-pay       <=50K    1.000
# Name: salary, dtype: float64

# %%
df3 = pd.DataFrame(citizen.groupby("workclass")["salary"].value_counts(normalize=True))

# %%
df3.columns=["percentages"]
df3.reset_index(inplace=True)
df3
# Out:
#            workclass salary  percentages
# 0        Federal-gov  <=50K        0.614
# 1        Federal-gov   >50K        0.386
# 2          Local-gov  <=50K        0.705
# 3          Local-gov   >50K        0.295
# 4       Never-worked  <=50K        1.000
# 5            Private  <=50K        0.781
# 6            Private   >50K        0.219
# 7       Self-emp-inc   >50K        0.557
# 8       Self-emp-inc  <=50K        0.443
# 9   Self-emp-not-inc  <=50K        0.715
# 10  Self-emp-not-inc   >50K        0.285
# 11         State-gov  <=50K        0.728
# 12         State-gov   >50K        0.272
# 13           Unknown  <=50K        0.896
# 14           Unknown   >50K        0.104
# 15       Without-pay  <=50K        1.000

# %%
ax = sns.barplot(data=df3,x="workclass", y="percentages", hue="salary");
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f');

# %%
citizen.groupby("salary")["workclass"].value_counts()
# Out:
# salary  workclass
# <=50K   Private             17733
#         Self-emp-not-inc     1817
#         Unknown              1645
#         Local-gov            1476
#         State-gov             945
#         Federal-gov           589
#         Self-emp-inc          494
#         Without-pay            14
#         Never-worked            7
# >50K    Private              4963
#         Self-emp-not-inc      724
#         Self-emp-inc          622
#         Local-gov             617
#         Federal-gov           371
#         State-gov             353
#         Unknown               191
# Name: workclass, dtype: int64

# %%
sns.countplot(data=citizen, x="salary", hue="workclass");

# %%
citizen.groupby("salary")["workclass"].value_counts(normalize=True)
# Out:
# salary  workclass
# <=50K   Private            0.717
#         Self-emp-not-inc   0.074
#         Unknown            0.067
#         Local-gov          0.060
#         State-gov          0.038
#         Federal-gov        0.024
#         Self-emp-inc       0.020
#         Without-pay        0.001
#         Never-worked       0.000
# >50K    Private            0.633
#         Self-emp-not-inc   0.092
#         Self-emp-inc       0.079
#         Local-gov          0.079
#         Federal-gov        0.047
#         State-gov          0.045
#         Unknown            0.024
# Name: workclass, dtype: float64

# %%
df4 = citizen.groupby("salary")["workclass"].value_counts(normalize=True).to_frame()
df4.columns = ["percentages"]
df4.reset_index(inplace=True)
df4
# Out:
#    salary         workclass  percentages
# 0   <=50K           Private        0.717
# 1   <=50K  Self-emp-not-inc        0.074
# 2   <=50K           Unknown        0.067
# 3   <=50K         Local-gov        0.060
# 4   <=50K         State-gov        0.038
# 5   <=50K       Federal-gov        0.024
# 6   <=50K      Self-emp-inc        0.020
# 7   <=50K       Without-pay        0.001
# 8   <=50K      Never-worked        0.000
# 9    >50K           Private        0.633
# 10   >50K  Self-emp-not-inc        0.092
# 11   >50K      Self-emp-inc        0.079
# 12   >50K         Local-gov        0.079
# 13   >50K       Federal-gov        0.047
# 14   >50K         State-gov        0.045
# 15   >50K           Unknown        0.024

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=df4,x="salary", y="percentages", hue="workclass");
for container in ax.containers:
    ax.bar_label(container, fmt='%.3f')
plt.legend(loc=(0.8,0.5));

# %% [markdown]
# #### Conclusions

# %% [markdown]
# Only for workclass self employed inc more people make more than 50K annually.

# %% [markdown]
# # Occupation

# %%
citizen.occupation.value_counts()
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %% [markdown]
# #### Replace the value "?" to the value "Unknown"

# %%
citizen.occupation.replace("?", "Unknown", inplace=True)

# %%
sns.countplot(data=citizen, x="occupation")
plt.xticks(rotation=90);

# %% [markdown]
# #### Feature by Salary Level

# %%
citizen.groupby("occupation").salary.value_counts(dropna=False)
# Out:
# occupation         salary
# Adm-clerical       <=50K     3263
#                    >50K       507
# Armed-Forces       <=50K        8
#                    >50K         1
# Craft-repair       <=50K     3170
#                    >50K       929
# Exec-managerial    <=50K     2098
#                    >50K      1968
# Farming-fishing    <=50K      879
#                    >50K       115
# Handlers-cleaners  <=50K     1284
#                    >50K        86
# Machine-op-inspct  <=50K     1752
#                    >50K       250
# Other-service      <=50K     3158
#                    >50K       137
# Priv-house-serv    <=50K      148
#                    >50K         1
# Prof-specialty     <=50K     2281
#                    >50K      1859
# Protective-serv    <=50K      438
#                    >50K       211
# Sales              <=50K     2667
#                    >50K       983
# Tech-support       <=50K      645
#                    >50K       283
# Transport-moving   <=50K     1277
# ...

# %%
sns.countplot(data=citizen, x="occupation", hue="salary")
plt.xticks(rotation=90);

# %%
citizen.groupby("occupation").salary.value_counts(normalize=True)
# Out:
# occupation         salary
# Adm-clerical       <=50K    0.866
#                    >50K     0.134
# Armed-Forces       <=50K    0.889
#                    >50K     0.111
# Craft-repair       <=50K    0.773
#                    >50K     0.227
# Exec-managerial    <=50K    0.516
#                    >50K     0.484
# Farming-fishing    <=50K    0.884
#                    >50K     0.116
# Handlers-cleaners  <=50K    0.937
#                    >50K     0.063
# Machine-op-inspct  <=50K    0.875
#                    >50K     0.125
# Other-service      <=50K    0.958
#                    >50K     0.042
# Priv-house-serv    <=50K    0.993
#                    >50K     0.007
# Prof-specialty     <=50K    0.551
#                    >50K     0.449
# Protective-serv    <=50K    0.675
#                    >50K     0.325
# Sales              <=50K    0.731
#                    >50K     0.269
# Tech-support       <=50K    0.695
#                    >50K     0.305
# Transport-moving   <=50K    0.800
# ...

# %%
df5 = citizen.groupby("occupation").salary.value_counts(normalize=True).to_frame()
df5.columns=["percentages"]
df5.reset_index(inplace=True)
df5.head()
# Out:
#      occupation salary  percentages
# 0  Adm-clerical  <=50K        0.866
# 1  Adm-clerical   >50K        0.134
# 2  Armed-Forces  <=50K        0.889
# 3  Armed-Forces   >50K        0.111
# 4  Craft-repair  <=50K        0.773

# %%
plt.figure(figsize=(16,9))
ax = sns.barplot(data=df5, x="occupation", y="percentages", hue="salary")
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f')
    
plt.xticks(rotation=90);

# %%
citizen.groupby("salary").occupation.value_counts()
# Out:
# salary  occupation
# <=50K   Adm-clerical         3263
#         Craft-repair         3170
#         Other-service        3158
#         Sales                2667
#         Prof-specialty       2281
#         Exec-managerial      2098
#         Machine-op-inspct    1752
#         Unknown              1652
#         Handlers-cleaners    1284
#         Transport-moving     1277
#         Farming-fishing       879
#         Tech-support          645
#         Protective-serv       438
#         Priv-house-serv       148
#         Armed-Forces            8
# >50K    Exec-managerial      1968
#         Prof-specialty       1859
#         Sales                 983
#         Craft-repair          929
#         Adm-clerical          507
#         Transport-moving      320
#         Tech-support          283
#         Machine-op-inspct     250
#         Protective-serv       211
#         Unknown               191
#         Other-service         137
#         Farming-fishing       115
# ...

# %%
sns.countplot(data=citizen, x="salary", hue="occupation");

# %%
citizen.groupby("salary").occupation.value_counts(normalize=True)
# Out:
# salary  occupation
# <=50K   Adm-clerical        0.132
#         Craft-repair        0.128
#         Other-service       0.128
#         Sales               0.108
#         Prof-specialty      0.092
#         Exec-managerial     0.085
#         Machine-op-inspct   0.071
#         Unknown             0.067
#         Handlers-cleaners   0.052
#         Transport-moving    0.052
#         Farming-fishing     0.036
#         Tech-support        0.026
#         Protective-serv     0.018
#         Priv-house-serv     0.006
#         Armed-Forces        0.000
# >50K    Exec-managerial     0.251
#         Prof-specialty      0.237
#         Sales               0.125
#         Craft-repair        0.118
#         Adm-clerical        0.065
#         Transport-moving    0.041
#         Tech-support        0.036
#         Machine-op-inspct   0.032
#         Protective-serv     0.027
#         Unknown             0.024
#         Other-service       0.017
#         Farming-fishing     0.015
# ...

# %%
df6 = citizen.groupby("salary").occupation.value_counts(normalize=True).to_frame()
df6.columns = ["percentages"]
df6.reset_index(inplace=True)
df6.head()
# Out:
#   salary      occupation  percentages
# 0  <=50K    Adm-clerical        0.132
# 1  <=50K    Craft-repair        0.128
# 2  <=50K   Other-service        0.128
# 3  <=50K           Sales        0.108
# 4  <=50K  Prof-specialty        0.092

# %%
plt.figure(figsize=(16,9))
ax = sns.barplot(data=df6, x="salary", y="percentages", hue="occupation")
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f');

# %% [markdown]
# #### Conclusion

# %% [markdown]
# Among people who make more than 50k annually management jobs and proffesional specialities make the most

# %% [markdown]
# # Race

# %%
citizen.race.value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
sns.countplot(data=citizen, x="race");

# %% [markdown]
# #### Feature by Salary Level

# %%
citizen.groupby("race").salary.value_counts()
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K       275
#                     >50K         36
# Asian-Pac-Islander  <=50K       763
#                     >50K        276
# Black               <=50K      2737
#                     >50K        387
# Other               <=50K       246
#                     >50K         25
# White               <=50K     20699
#                     >50K       7117
# Name: salary, dtype: int64

# %%
sns.countplot(data=citizen, x="race", hue="salary");

# %% [markdown]
# #### Let's check the percentage distribution of person in each "salary" levels by each races and visualize it with pie plot

# %%
citizen.groupby("race").salary.value_counts(normalize=True)
# Out:
# race                salary
# Amer-Indian-Eskimo  <=50K    0.884
#                     >50K     0.116
# Asian-Pac-Islander  <=50K    0.734
#                     >50K     0.266
# Black               <=50K    0.876
#                     >50K     0.124
# Other               <=50K    0.908
#                     >50K     0.092
# White               <=50K    0.744
#                     >50K     0.256
# Name: salary, dtype: float64

# %%
colors = ['pink', 'lightblue']

g = citizen.groupby("race")["salary"].value_counts().unstack(level=0)

ax = g.plot.pie(subplots=True,figsize=(18, 12), layout=(2,3),
                title=["Amer-Indian-Eskimo", "Asian-Pac-Islander", "Black", "Other", "White"], ylabel="Salary",
                autopct='%1.1f%%', legend=False, colors=colors);

# %%
citizen.groupby("salary").race.value_counts()
# Out:
# salary  race
# <=50K   White                 20699
#         Black                  2737
#         Asian-Pac-Islander      763
#         Amer-Indian-Eskimo      275
#         Other                   246
# >50K    White                  7117
#         Black                   387
#         Asian-Pac-Islander      276
#         Amer-Indian-Eskimo       36
#         Other                    25
# Name: race, dtype: int64

# %%
sns.countplot(data=citizen, x="salary", hue="race");

# %%
citizen.groupby("salary").race.value_counts(normalize=True)
# Out:
# salary  race
# <=50K   White                0.837
#         Black                0.111
#         Asian-Pac-Islander   0.031
#         Amer-Indian-Eskimo   0.011
#         Other                0.010
# >50K    White                0.908
#         Black                0.049
#         Asian-Pac-Islander   0.035
#         Amer-Indian-Eskimo   0.005
#         Other                0.003
# Name: race, dtype: float64

# %%
df7 = citizen.groupby("salary").race.value_counts(normalize=True).to_frame()
df7.columns = ["percentages"]
df7.reset_index(inplace=True)
df7.head()
# Out:
#   salary                race  percentages
# 0  <=50K               White        0.837
# 1  <=50K               Black        0.111
# 2  <=50K  Asian-Pac-Islander        0.031
# 3  <=50K  Amer-Indian-Eskimo        0.011
# 4  <=50K               Other        0.010

# %%
ax = sns.barplot(data=df7, x="salary", y="percentages", hue="race")

for container in ax.containers:
    ax.bar_label(container, fmt='%.3f');

# %% [markdown]
# #### Conclusions

# %% [markdown]
# More White people and asian pacific people tend to make more than 50k

# %% [markdown]
# # Gender

# %%
citizen.sex.value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
sns.countplot(data=citizen, x="sex");

# %% [markdown]
# #### Feature by Salary

# %%
citizen.groupby("sex").salary.value_counts()
# Out:
# sex     salary
# Female  <=50K      9592
#         >50K       1179
# Male    <=50K     15128
#         >50K       6662
# Name: salary, dtype: int64

# %%
sns.countplot(data=citizen, x="sex", hue="salary");

# %% [markdown]
# #### Let's check the percentage distribution of person in each "salary" levels by each gender and visualize it with pie plot

# %%
citizen.groupby("sex").salary.value_counts(normalize=True)
# Out:
# sex     salary
# Female  <=50K    0.891
#         >50K     0.109
# Male    <=50K    0.694
#         >50K     0.306
# Name: salary, dtype: float64

# %%
df8 = citizen.groupby("sex").salary.value_counts(normalize=True).to_frame()
df8.columns = ["percentages"]
df8.reset_index(inplace=True)
df8.head()
# Out:
#       sex salary  percentages
# 0  Female  <=50K        0.891
# 1  Female   >50K        0.109
# 2    Male  <=50K        0.694
# 3    Male   >50K        0.306

# %%
colors = ['pink', 'lightblue']

h = citizen.groupby("sex").salary.value_counts().unstack(level=0)
ax = h.plot(kind="pie", subplots=True,figsize=(15, 6), 
            title=["Female", "Male"], ylabel="Salary",
            autopct='%1.1f%%', legend=False, colors=colors);

# %%
citizen.groupby("salary").sex.value_counts()
# Out:
# salary  sex
# <=50K   Male      15128
#         Female     9592
# >50K    Male       6662
#         Female     1179
# Name: sex, dtype: int64

# %%
sns.countplot(data=citizen, x="salary", hue="sex");

# %%
colors = ['pink', 'lightblue']

h = citizen.groupby("salary").sex.value_counts().unstack(level=0)
ax = h.plot.pie(subplots=True,figsize=(15, 6), 
                title=["<=50K", ">50K"], ylabel="Gender",
                autopct='%1.1f%%', legend=False, colors=colors);

# %% [markdown]
# #### Conclusion

# %% [markdown]
# Men make more money compared to women.

# %% [markdown]
# # Native Country

# %%
citizen.native_country.value_counts(dropna=False)
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %% [markdown]
# #### Replace the value "?" to the value "Unknown"

# %%
citizen.native_country.replace("?", "Unknown", inplace=True)

# %%
sns.countplot(data=citizen, x="native_country")
plt.xticks(rotation=90);

# %% [markdown]
# #### Decrease the number of categories in "native_country" feature as US, and Others and create a new feature with this new categorical data

# %%
def mapping_native_country(country):
    if country == "United-States":
        return "US"
    else:
        return "Others"

# %%
citizen["native_country_summary"] = citizen.native_country.transform(mapping_native_country)

# %%
citizen["native_country_summary"].value_counts()
# Out:
# US        29170
# Others     3391
# Name: native_country_summary, dtype: int64

# %%
sns.countplot(citizen["native_country_summary"]);

# %% [markdown]
# #### Feature by Salary

# %%
citizen.groupby("native_country_summary").salary.value_counts()
# Out:
# native_country_summary  salary
# Others                  <=50K      2721
#                         >50K        670
# US                      <=50K     21999
#                         >50K       7171
# Name: salary, dtype: int64

# %%
sns.countplot(data=citizen, x="native_country_summary", hue="salary");

# %% [markdown]
# #### Let's check the percentage distribution of person in each "salary" levels by each new native countries (US, Others) and visualize it with pie plot separately

# %%
citizen.groupby("native_country_summary").salary.value_counts(normalize=True)
# Out:
# native_country_summary  salary
# Others                  <=50K    0.802
#                         >50K     0.198
# US                      <=50K    0.754
#                         >50K     0.246
# Name: salary, dtype: float64

# %%
colors = ['pink', 'lightblue']

i = citizen.groupby("native_country_summary").salary.value_counts().unstack(level=0)
ax = i.plot.pie(subplots=True,figsize=(15, 6), 
                title=["Others", "US"], ylabel="Salary",
                autopct='%1.1f%%', legend=False, colors=colors);

# %%
citizen.groupby("salary").native_country_summary.value_counts()
# Out:
# salary  native_country_summary
# <=50K   US                        21999
#         Others                     2721
# >50K    US                         7171
#         Others                      670
# Name: native_country_summary, dtype: int64

# %%
sns.countplot(data=citizen, x="salary", hue="sex");

# %%
citizen.groupby("salary").native_country_summary.value_counts(normalize=True)
# Out:
# salary  native_country_summary
# <=50K   US                       0.890
#         Others                   0.110
# >50K    US                       0.915
#         Others                   0.085
# Name: native_country_summary, dtype: float64

# %%
colors = ['pink', 'lightblue']

i = citizen.groupby("salary").native_country_summary.value_counts().unstack(level=0)
ax = i.plot.pie(subplots=True,figsize=(15, 6), 
                title=["<=50K", ">50K"], ylabel="Native Country",
                autopct='%1.2f%%', legend=False, colors=colors);

# %% [markdown]
# #### Conclusion

# %% [markdown]
# United States has a high ratio of high-level income both in the self group and in the high-income group.

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Other Specific Analysis Questions</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. What is the average age of males and females by income level?

# %%
citizen.groupby(["salary", "sex"]).age.mean()
# Out:
# salary  sex
# <=50K   Female   36.211
#         Male     37.147
# >50K    Female   42.126
#         Male     44.626
# Name: age, dtype: float64

# %%
j = citizen.groupby(["salary", "sex"]).age.mean()

ax = j.plot(kind="bar");

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f');

# %%
ax = sns.barplot(data=citizen, x="salary", y="age", hue="sex")
for container in ax.containers:
    ax.bar_label(container, fmt='%.2f');

# %% [markdown]
# ### 2. What is the workclass percentages of Americans in high-level income group?

# %%
df9 = (citizen[citizen["salary"] == ">50K"]["workclass"].value_counts(normalize=True)*100).to_frame()
df9.reset_index(inplace=True)
df9.columns=["workclass","percentages"]
df9
# Out:
#           workclass  percentages
# 0           Private       63.295
# 1  Self-emp-not-inc        9.234
# 2      Self-emp-inc        7.933
# 3         Local-gov        7.869
# 4       Federal-gov        4.732
# 5         State-gov        4.502
# 6           Unknown        2.436

# %%
ax = sns.barplot(data=df9, x="workclass", y="percentages")

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f');

# %% [markdown]
# ### 3. What is the occupation percentages of Americans who work as "Private" workclass in high-level income group?

# %%
df10 = (citizen[(citizen["salary"] == ">50K") & (citizen["workclass"] == "Private")]["occupation"].value_counts(normalize=True)*100).to_frame()
df10.reset_index(inplace=True)
df10.columns=["occupation", "percentages"]
df10
# Out:
#            occupation  percentages
# 0     Exec-managerial       26.093
# 1      Prof-specialty       20.310
# 2        Craft-repair       14.528
# 3               Sales       13.782
# 4        Adm-clerical        6.468
# 5    Transport-moving        5.118
# 6   Machine-op-inspct        4.534
# 7        Tech-support        4.453
# 8       Other-service        2.015
# 9   Handlers-cleaners        1.471
# 10    Farming-fishing        0.604
# 11    Protective-serv        0.604
# 12    Priv-house-serv        0.020

# %%
ax = sns.barplot(data=df10, x="occupation", y="percentages")
plt.xticks(rotation=45)

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f');

# %% [markdown]
# ### 4. What is the education level percentages of Asian-Pac-Islander race group in high-level income group?

# %%
df11 = (citizen[(citizen["salary"] == ">50K") & (citizen["race"] == "Asian-Pac-Islander")]["education"].value_counts(normalize=True)*100).to_frame()
df11.reset_index(inplace=True)
df11.columns=["education", "percentages"]
df11
# Out:
#        education  percentages
# 0      Bachelors       35.145
# 1        Masters       15.580
# 2        HS-grad       12.319
# 3   Some-college       11.957
# 4    Prof-school        9.783
# 5      Doctorate        6.522
# 6      Assoc-voc        3.261
# 7     Assoc-acdm        2.899
# 8        5th-6th        1.087
# 9            9th        0.362
# 10          11th        0.362
# 11          10th        0.362
# 12          12th        0.362

# %%
ax = sns.barplot(data=df11, x="education", y="percentages")
plt.xticks(rotation=45)

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f');

# %%
df12 = (citizen[(citizen["salary"] == ">50K") & (citizen["race"] == "Asian-Pac-Islander")]["education_summary"].value_counts(normalize=True)*100).to_frame()
df12.reset_index(inplace=True)
df12.columns=["education_summary", "percentages"]
df12
# Out:
#   education_summary  percentages
# 0     high_level_ed       67.029
# 1   medium_level_ed       30.435
# 2      low_level_ed        2.536

# %%
ax = sns.barplot(data=df12, x="education_summary", y="percentages")

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f');

# %% [markdown]
# ### 5. What is the occupation percentages of Asian-Pac-Islander race group who has a Bachelors degree in high-level income group?

# %%
df13 = (citizen[(citizen["salary"] == ">50K") & (citizen["education"] == "Bachelors") & (citizen["race"] == "Asian-Pac-Islander")]["occupation"].value_counts(normalize=True)*100).to_frame()
df13.reset_index(inplace=True)
df13.columns=["occupation", "percentages"]
df13
# Out:
#            occupation  percentages
# 0     Exec-managerial       27.835
# 1      Prof-specialty       25.773
# 2        Adm-clerical       12.371
# 3               Sales        9.278
# 4       Other-service        9.278
# 5        Craft-repair        7.216
# 6        Tech-support        3.093
# 7     Protective-serv        2.062
# 8    Transport-moving        1.031
# 9   Machine-op-inspct        1.031
# 10    Farming-fishing        1.031

# %%
ax = sns.barplot(data=df13, x="occupation", y="percentages")
plt.xticks(rotation=45)

for container in ax.containers:
    ax.bar_label(container, fmt='%.2f');

# %% [markdown]
# ### 6. What is the mean of working hours per week by gender for education level, workclass and marital status? Try to plot all required in one figure.

# %%
citizen.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors         13.000
# 1   50  Self-emp-not-inc   83311  Bachelors         13.000
# 2   38           Private  215646    HS-grad          9.000
# 3   53           Private  234721       11th          7.000
# 4   28           Private  338409  Bachelors         13.000
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country salary  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
citizen.groupby("sex")["hours_per_week"].mean()
# Out:
# sex
# Female   36.410
# Male     42.428
# Name: hours_per_week, dtype: float64

# %%
ax = sns.catplot(x="education_summary", y="hours_per_week", data=citizen, estimator=np.mean, hue="sex", col="native_country_summary", row="marital_status_summary", kind="bar", palette="pastel", ci=None, height=6, aspect=1.5)

ax.fig.suptitle('Working Hours by Gender for Education Levels, Native Country and Marital Status', y=1.05, fontsize=18);

#ax = z.facet_axis(1,1)
#for p in ax.patches:
    #ax.text(p.get_x() + 0.015, 
            #p.get_height() * 1.02, 
            #'{0:.2f}'.format(p.get_height()), 
            #color='black', rotation='horizontal', size='large')

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dropping Similar & Unneccessary Features</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# #### Let's drop unnecessary features;

# %%
citizen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     32561 non-null  int64
#  1   workclass               32561 non-null  object
#  2   fnlwgt                  32561 non-null  int64
#  3   education               32561 non-null  object
#  4   education_num           32561 non-null  float64
#  5   marital_status          32561 non-null  object
#  6   occupation              32561 non-null  object
#  7   relationship            32561 non-null  object
#  8   race                    32561 non-null  object
#  9   sex                     32561 non-null  object
#  10  capital_gain            32561 non-null  int64
#  11  capital_loss            32561 non-null  int64
#  12  hours_per_week          32561 non-null  int64
#  13  native_country          32561 non-null  object
# ...

# %%
citizen.drop(["education", "education_num", "marital_status", "relationship", "native_country"], inplace=True, axis=1)

# %%
citizen.head()
# Out:
#    age         workclass  fnlwgt         occupation   race     sex  \
# 0   39         State-gov   77516       Adm-clerical  White    Male
# 1   50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2   38           Private  215646  Handlers-cleaners  White    Male
# 3   53           Private  234721  Handlers-cleaners  Black    Male
# 4   28           Private  338409     Prof-specialty  Black  Female
#
#    capital_gain  capital_loss  hours_per_week salary education_summary  \
# 0          2174             0              40  <=50K     high_level_ed
# 1             0             0              13  <=50K     high_level_ed
# 2             0             0              40  <=50K   medium_level_ed
# 3             0             0              40  <=50K      low_level_ed
# 4             0             0              40  <=50K     high_level_ed
#
#   marital_status_summary native_country_summary
# 0              unmarried                     US
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Missing Value</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# #### Let's check the missing values for all features basically

# %%
citizen.isnull().sum()
# Out:
# age                       0
# workclass                 0
# fnlwgt                    0
# occupation                0
# race                      0
# sex                       0
# capital_gain              0
# capital_loss              0
# hours_per_week            0
# salary                    0
# education_summary         0
# marital_status_summary    0
# native_country_summary    0
# dtype: int64

# %% [markdown]
# #### There isn't any NaN value but Unknown values in columns "Workclass" and "Education". Let's see the percentage of these values in their columns:

# %%
citizen[citizen["workclass"] == "Unknown"]["workclass"].value_counts()/citizen["workclass"].value_counts().sum()*100
# Out:
# Unknown   5.639
# Name: workclass, dtype: float64

# %%
citizen[citizen["occupation"] == "Unknown"]["occupation"].value_counts()/citizen["occupation"].value_counts().sum()*100
# Out:
# Unknown   5.660
# Name: occupation, dtype: float64

# %% [markdown]
# #### These values are only 5% of the column, so we may drop them.

# %%
citizen.workclass.replace("Unknown", np.nan, inplace=True)

# %%
citizen.workclass.value_counts(dropna=False)
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# NaN                  1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
citizen.occupation.replace("Unknown", np.nan, inplace=True)

# %%
citizen.occupation.value_counts(dropna=False)
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# NaN                  1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
citizen.dropna(inplace=True)

# %%
citizen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30718 entries, 0 to 32560
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     30718 non-null  int64
#  1   workclass               30718 non-null  object
#  2   fnlwgt                  30718 non-null  int64
#  3   occupation              30718 non-null  object
#  4   race                    30718 non-null  object
#  5   sex                     30718 non-null  object
#  6   capital_gain            30718 non-null  int64
#  7   capital_loss            30718 non-null  int64
#  8   hours_per_week          30718 non-null  int64
#  9   salary                  30718 non-null  object
#  10  education_summary       30718 non-null  object
#  11  marital_status_summary  30718 non-null  object
#  12  native_country_summary  30718 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Handling with Outliers</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# #### Boxplot and Histplot for all numeric features
# #### Plot boxplots for each numeric features at the same figure as subplots

# %%
sns.boxplot(data=citizen);

# %%
fig, ax = plt.subplots(2, 3, figsize=(20, 12))

sns.boxplot(data=citizen, x="age", ax=ax[0,0])
ax[0,0].set_xlabel('age')

sns.boxplot(data=citizen, x='fnlwgt', ax=ax[0,1])
ax[0,1].set_xlabel('fnlwgt')

sns.boxplot(data=citizen, x='capital_gain', ax=ax[0,2])
ax[0,2].set_xlabel('capital_gain')

sns.boxplot(data=citizen, x='capital_loss', ax=ax[1,0])
ax[1,1].set_xlabel('capital_loss')

sns.boxplot(data=citizen, x='hours_per_week', ax=ax[1,1])
ax[1,2].set_xlabel('hours_per_week');

# %%
fig, ax = plt.subplots(5, 2, figsize=(15, 20))

sns.boxplot(data=citizen, x="age", ax=ax[0,0])
ax[0,0].set_xlabel('age')

sns.histplot(data=citizen, x="age", ax=ax[0,1])
ax[0,1].set_xlabel('age')

sns.boxplot(data=citizen, x='fnlwgt', ax=ax[1,0])
ax[1,0].set_xlabel('fnlwgt')

sns.histplot(data=citizen, x='fnlwgt', ax=ax[1,1])
ax[1,1].set_xlabel('fnlwgt')

sns.boxplot(data=citizen, x='capital_gain', ax=ax[2,0])
ax[2,0].set_xlabel('capital_gain')

sns.histplot(data=citizen, x='capital_gain', ax=ax[2,1])
ax[2,1].set_xlabel('capital_gain')

sns.boxplot(data=citizen, x='capital_loss', ax=ax[3,0])
ax[3,0].set_xlabel('capital_loss')

sns.histplot(data=citizen, x='capital_loss', ax=ax[3,1])
ax[3,1].set_xlabel('capital_loss')

sns.boxplot(data=citizen, x='hours_per_week', ax=ax[4,0])
ax[4,0].set_xlabel('hours_per_week')

sns.histplot(data=citizen, x='hours_per_week', ax=ax[4,1])
ax[4,1].set_xlabel('hours_per_week');

# %%
citizen[["age", "fnlwgt", "capital_gain", "capital_loss", "hours_per_week"]].describe().T
# Out:
#                    count       mean        std       min        25%  \
# age            30718.000     38.444     13.118    17.000     28.000
# fnlwgt         30718.000 189845.546 105458.310 13769.000 117828.500
# capital_gain   30718.000   1106.037   7497.863     0.000      0.000
# capital_loss   30718.000     88.910    405.657     0.000      0.000
# hours_per_week 30718.000     40.949     11.985     1.000     40.000
#
#                       50%        75%         max
# age                37.000     47.000      90.000
# fnlwgt         178517.000 237317.000 1484705.000
# capital_gain        0.000      0.000   99999.000
# capital_loss        0.000      0.000    4356.000
# hours_per_week     40.000     45.000      99.000

# %% [markdown]
# #### 1. After analyzing all features, we can see that we can't evaluate extreme values in "fnlwgt, capital_gain, capital_loss" features in the scope of outliers.
# #### 2. We need to focus on the "age and hours_per_week" features and detect the outliers by using IQR Rule.

# %% [markdown]
# # Age

# %% [markdown]
# #### We find iqr, q1 and q3 values;

# %%
q1 = citizen.age.quantile(0.25)
q2 = citizen.age.quantile(0.50)
q3 = citizen.age.quantile(0.75)
iqr = q3-q1
print([q1 ,q3, iqr])
# Out:
# [28.0, 47.0, 19.0]

# %% [markdown]
# #### Finding the lower and upper limit using IQR;

# %%
upper_limit_age = q3+iqr*1.5
lower_limit_age = q1-iqr*1.5
print(lower_limit_age, upper_limit_age)
# Out:
# -0.5 75.5

# %%
citizen[citizen["age"] > upper_limit_age]["age"].value_counts()
# Out:
# 90    36
# 76    30
# 77    20
# 80    16
# 79    15
# 81    14
# 78    14
# 84     8
# 82     7
# 83     5
# 88     3
# 85     3
# 86     1
# Name: age, dtype: int64

# %%
citizen[citizen["age"] > upper_limit_age].sort_values(by="age", ascending=False)
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 19747   90           Private  226968  Machine-op-inspct  White    Male
# 6232    90  Self-emp-not-inc  155981     Prof-specialty  White    Male
# 4070    90           Private  313986  Handlers-cleaners  White    Male
# 24043   90  Self-emp-not-inc   82628    Exec-managerial  White    Male
# 28463   90       Federal-gov  195433       Craft-repair  White    Male
# ...    ...               ...     ...                ...    ...     ...
# 15102   76         Local-gov  169133       Adm-clerical  White  Female
# 19085   76           Private  125784    Exec-managerial  White    Male
# 23515   76           Private  142535       Adm-clerical  White    Male
# 8240    76  Self-emp-not-inc  225964              Sales  White    Male
# 23354   76           Private  199949       Adm-clerical  White    Male
#
#        capital_gain  capital_loss  hours_per_week salary education_summary  \
# ...

# %% [markdown]
# # Hours per Week

# %% [markdown]
# #### We find iqr, q1 and q3 values;

# %%
q1 = citizen.hours_per_week.quantile(0.25)
q2 = citizen.hours_per_week.quantile(0.50)
q3 = citizen.hours_per_week.quantile(0.75)
iqr = q3-q1
print([q1 ,q3, iqr])
# Out:
# [40.0, 45.0, 5.0]

# %% [markdown]
# #### Finding the lower and upper limit using IQR;

# %%
upper_limit_hour = q3+iqr*1.5
lower_limit_hour = q1-iqr*1.5
print(lower_limit_hour, upper_limit_hour)
# Out:
# 32.5 52.5

# %% [markdown]
# Let's define the observations where  hours per week are greater than upper limit and lower than the lower limit and sort these observations by hours per week in descending order

# %%
citizen[citizen["hours_per_week"] > upper_limit_hour]["hours_per_week"].value_counts().sort_index(ascending=False)
# Out:
# 99      80
# 98      11
# 97       2
# 96       5
# 95       2
# 94       1
# 92       1
# 91       3
# 90      28
# 89       2
# 88       2
# 87       1
# 86       2
# 85      13
# 84      41
# 82       1
# 81       3
# 80     124
# 78       8
# 77       6
# 76       3
# 75      63
# 74       1
# 73       2
# 72      68
# 70     284
# 68      12
# 67       4
# 66      17
# 65     242
# 64      14
# 63      10
# 62      18
# 61       2
# 60    1441
# 59       5
# 58      27
# 57      17
# 56      91
# 55     684
# 54      39
# 53      23
# Name: hours_per_week, dtype: int64

# %%
citizen[citizen["hours_per_week"] < lower_limit_hour]["hours_per_week"].value_counts().sort_index(ascending=True)
# Out:
# 1        8
# 2       15
# 3       24
# 4       28
# 5       39
# 6       40
# 7       20
# 8      103
# 9       17
# 10     226
# 11       9
# 12     143
# 13      19
# 14      29
# 15     350
# 16     182
# 17      27
# 18      64
# 19      14
# 20    1066
# 21      23
# 22      39
# 23      20
# 24     220
# 25     582
# 26      30
# 27      28
# 28      74
# 29       6
# 30    1010
# 31       5
# 32     239
# Name: hours_per_week, dtype: int64

# %% [markdown]
# Let's have a look at the statisctical values of rows lower than the lower limit of hours per week;

# %%
citizen[citizen["hours_per_week"] < lower_limit_hour].groupby("salary")["hours_per_week"].describe()
# Out:
#           count   mean   std   min    25%    50%    75%    max
# salary
# <=50K  4377.000 21.541 7.347 1.000 16.000 20.000 30.000 32.000
# >50K    322.000 22.028 7.813 1.000 18.000 24.000 30.000 32.000

# %%
citizen[citizen["hours_per_week"] < lower_limit_hour].groupby("salary")["age"].describe()
# Out:
#           count   mean    std    min    25%    50%    75%    max
# salary
# <=50K  4377.000 34.036 17.726 17.000 20.000 26.000 45.000 90.000
# >50K    322.000 49.484 13.894 22.000 39.000 48.000 60.000 90.000

# %% [markdown]
# #### Result :

# %% [markdown]
# As we see, there are number of extreme values in both "age and hours_per_week" features. But how can we know if these extreme values are outliers or not? At this point, domain knowledge comes to the fore.
# Domain Knowledge for this dataset:
# In this dataset, all values are created according to the statements of individuals. So It can be some "data entries errors".
# In addition, we have aimed to create an ML model with some restrictions as getting better performance from the ML model.
# In this respect, our sample space ranges for some features are as follows.
# age : 17 to 80
# hours_per_week : 7 to 70
# if somebody's age is more than 60, he/she can't work more than 60 hours in a week

# %% [markdown]
# ### Dropping rows according to the domain knownledge

# %% [markdown]
# ##### We create a condition according to the domain knowledge on age and drop these rows

# %%
df2 = citizen[(citizen["age"] > 80) | (citizen["age"] < 17)].sort_values(by="age", ascending=False)
df2
# Out:
#        age         workclass  fnlwgt         occupation   race     sex  \
# 222     90           Private   51744      Other-service  Black    Male
# 19747   90           Private  226968  Machine-op-inspct  White    Male
# 8806    90           Private   87372     Prof-specialty  White    Male
# 8973    90           Private   46786              Sales  White    Male
# 20610   90           Private  206667     Prof-specialty  White  Female
# ...    ...               ...     ...                ...    ...     ...
# 4834    81           Private  364099       Adm-clerical  White  Female
# 918     81  Self-emp-not-inc  136063    Exec-managerial  White    Male
# 3537    81  Self-emp-not-inc  137018       Adm-clerical  White  Female
# 2906    81           Private  114670    Priv-house-serv  Black  Female
# 19045   81         State-gov  132204      Other-service  White  Female
#
#        capital_gain  capital_loss  hours_per_week salary education_summary  \
# ...

# %%
df2.shape
# Out:
# (77, 13)

# %%
age_index = df2.index
age_index
# Out:
# Int64Index([  222, 19747,  8806,  8973, 20610, 10210, 10545, 11512, 11996,
#             12975, 15892, 19489, 19212, 18832, 14159, 18725, 18413, 15356,
#             22220, 18277,  5104,  5272,  2891, 32367, 32277,  4070, 31030,
#             24043,  2303,  1935,  5370,  5406, 28463,  6232,  6624,  1040,
#              1168, 22895, 21835, 24027, 20463, 32459,  8381, 14711,  6214,
#             27795, 26731, 11238,  9471,  7720, 15662, 16302, 19172, 24395,
#              7481, 23459, 31855, 24280, 22481,  8431, 13696, 14756, 20421,
#             12830,  6748, 19495, 13295, 24560, 21501, 13928, 28948, 29594,
#              4834,   918,  3537,  2906, 19045],
#            dtype='int64')

# %%
citizen.drop(axis=0, index=age_index, inplace=True)
citizen.shape
# Out:
# (30641, 13)

# %%
df3 = citizen[(citizen["hours_per_week"] < 7) | (citizen["hours_per_week"] > 70)].sort_values(by="hours_per_week", ascending=False)
df3
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 22216   45           Private   54260      Craft-repair               White
# 5432    44           Private   83508    Prof-specialty               White
# 19053   27           Private   40295  Transport-moving               White
# 19141   59           Private  106748     Other-service               White
# 19399   39      Self-emp-inc  163057      Craft-repair               White
# ...    ...               ...     ...               ...                 ...
# 20909   77  Self-emp-not-inc   71676      Adm-clerical               White
# 25078   74           Private  260669     Other-service               White
# 19750   23           Private   72887      Craft-repair  Asian-Pac-Islander
# 189     58         State-gov  109567    Prof-specialty               White
# 24284   57  Self-emp-not-inc   56480   Exec-managerial               White
#
#           sex  capital_gain  capital_loss  hours_per_week salary  \
# ...

# %% [markdown]
# ##### We create a condition according to the domain knowledge on hours per week stated above and drop these rows

# %%
hours_index = df3.index
hours_index
# Out:
# Int64Index([22216,  5432, 19053, 19141, 19399, 19529, 19731, 19997, 20036,
#             21056,
#             ...
#              6180, 29867,  1036, 11451, 22960, 20909, 25078, 19750,   189,
#             24284],
#            dtype='int64', length=621)

# %%
citizen.drop(axis=0, index=hours_index, inplace=True)
citizen.shape
# Out:
# (30020, 13)

# %%
df4 = citizen[(citizen["hours_per_week"] > 60) & (citizen["age"] > 60)].sort_values(by="hours_per_week", ascending=False)
df4
# Out:
#        age         workclass  fnlwgt        occupation                race  \
# 1541    62           Private  162245    Prof-specialty               White
# 12624   63      Self-emp-inc  110890    Prof-specialty               White
# 31342   62  Self-emp-not-inc  173631   Exec-managerial               White
# 27721   61         Local-gov   28375    Prof-specialty               White
# 25910   66      Self-emp-inc  179951   Exec-managerial               White
# 23399   63  Self-emp-not-inc   28612             Sales               White
# 20125   62           Private  252668    Prof-specialty               White
# 19584   64  Self-emp-not-inc  192695   Farming-fishing               White
# 2154    75           Private  101887   Priv-house-serv               White
# 18367   70  Self-emp-not-inc  139889   Farming-fishing               White
# 6826    68           Private  284763  Transport-moving               White
# ...

# %% [markdown]
# ##### We create a condition according to the domain knowledge on both age and hours per week stated above and drop these rows

# %%
age_hour_index = df4.index
age_hour_index
# Out:
# Int64Index([ 1541, 12624, 31342, 27721, 25910, 23399, 20125, 19584,  2154,
#             18367,  6826,  5417,  2665,  2184,  9646, 16634, 23585, 24903,
#              3101, 26625, 28294, 32192,  8066],
#            dtype='int64')

# %%
citizen.drop(axis=0, index=age_hour_index, inplace=True)
citizen.shape
# Out:
# (29997, 13)

# %%
citizen.reset_index(inplace=True, drop=True)

# %%
citizen.head()
# Out:
#    age         workclass  fnlwgt         occupation   race     sex  \
# 0   39         State-gov   77516       Adm-clerical  White    Male
# 1   50  Self-emp-not-inc   83311    Exec-managerial  White    Male
# 2   38           Private  215646  Handlers-cleaners  White    Male
# 3   53           Private  234721  Handlers-cleaners  Black    Male
# 4   28           Private  338409     Prof-specialty  Black  Female
#
#    capital_gain  capital_loss  hours_per_week salary education_summary  \
# 0          2174             0              40  <=50K     high_level_ed
# 1             0             0              13  <=50K     high_level_ed
# 2             0             0              40  <=50K   medium_level_ed
# 3             0             0              40  <=50K      low_level_ed
# 4             0             0              40  <=50K     high_level_ed
#
#   marital_status_summary native_country_summary
# 0              unmarried                     US
# ...

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Final Step to Make the Dataset Ready for ML Models</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# ### 1. Convert all features to numeric

# %% [markdown]
# #### Converting target feature (salary) to numeric (0 and 1) by using map function

# %%
citizen["salary"] = citizen["salary"].map({"<=50K" : 0, ">50K" : 1})

# %%
citizen["salary"].value_counts()
# Out:
# 0    22545
# 1     7452
# Name: salary, dtype: int64

# %% [markdown]
# #### Converting all features to numeric by using get_dummies function

# %%
citizen_dummy = pd.get_dummies(citizen, drop_first=True)

# %%
citizen_dummy.head()
# Out:
#    age  fnlwgt  capital_gain  capital_loss  hours_per_week  salary  \
# 0   39   77516          2174             0              40       0
# 1   50   83311             0             0              13       0
# 2   38  215646             0             0              40       0
# 3   53  234721             0             0              40       0
# 4   28  338409             0             0              40       0
#
#    workclass_Local-gov  workclass_Private  workclass_Self-emp-inc  \
# 0                    0                  0                       0
# 1                    0                  0                       0
# 2                    0                  1                       0
# 3                    0                  1                       0
# 4                    0                  1                       0
#
#    workclass_Self-emp-not-inc  workclass_State-gov  workclass_Without-pay  \
# 0                           0                    1                      0
# ...

# %%
citizen_dummy.shape
# Out:
# (29997, 34)

# %%
citizen.shape
# Out:
# (29997, 13)

# %% [markdown]
# ### 2. Let's take a look at correlation between features by utilizing power of visualizing

# %%
citizen_dummy.corr()
# Out:
#                                      age  fnlwgt  capital_gain  capital_loss  \
# age                                1.000  -0.074         0.082         0.059
# fnlwgt                            -0.074   1.000        -0.002        -0.011
# capital_gain                       0.082  -0.002         1.000        -0.032
# capital_loss                       0.059  -0.011        -0.032         1.000
# hours_per_week                     0.119  -0.019         0.086         0.060
# salary                             0.253  -0.010         0.222         0.152
# workclass_Local-gov                0.070  -0.004        -0.010         0.015
# workclass_Private                 -0.212   0.045        -0.045        -0.039
# workclass_Self-emp-inc             0.111  -0.025         0.093         0.031
# workclass_Self-emp-not-inc         0.146  -0.037         0.033         0.023
# workclass_State-gov                0.020  -0.012        -0.013        -0.002
# ...

# %%
plt.figure(figsize=(18,10))
sns.heatmap(citizen_dummy.corr(), cmap="coolwarm", annot=True, center=0.8);

# %%
target = citizen_dummy.corr()[["salary"]].sort_values(by="salary", ascending=False)
target
# Out:
#                                    salary
# salary                              1.000
# age                                 0.253
# hours_per_week                      0.247
# capital_gain                        0.222
# sex_Male                            0.216
# occupation_Exec-managerial          0.215
# occupation_Prof-specialty           0.185
# capital_loss                        0.152
# workclass_Self-emp-inc              0.138
# race_White                          0.086
# native_country_summary_US           0.036
# workclass_Self-emp-not-inc          0.030
# workclass_Local-gov                 0.029
# occupation_Protective-serv          0.026
# occupation_Tech-support             0.023
# occupation_Sales                    0.015
# race_Asian-Pac-Islander             0.012
# workclass_State-gov                 0.011
# occupation_Armed-Forces            -0.006
# fnlwgt                             -0.010
# workclass_Without-pay              -0.012
# ...

# %%
plt.figure(figsize=(4,10))

sns.heatmap(target, annot=True, cmap="viridis_r", vmin=-1, vmax=1, center=-0.5);

# %%
plt.figure(figsize=(5,20))

sns.barplot(data=target, y=target.index, x="salary");

# %% [markdown]
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of the Project</p>
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ___
